# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

# %%
dataframe = pd.read_csv("Housing.csv")

# %%
dataframe.head(2)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished

# %%
dataframe.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
print(dataframe.isna().count())
dataframe.duplicated().count()
x = dataframe.price /1e6
# Out:
# price               545
# area                545
# bedrooms            545
# bathrooms           545
# stories             545
# mainroad            545
# guestroom           545
# basement            545
# hotwaterheating     545
# airconditioning     545
# parking             545
# prefarea            545
# furnishingstatus    545
# dtype: int64

# %%
plt.scatter(dataframe.area,dataframe.price)

# %%
plt.scatter(dataframe.bedrooms,dataframe.price)

# %%
plt.scatter(dataframe.bathrooms,dataframe.price)
# Out:
# <BarContainer object of 545 artists>

# %%
plt.scatter(dataframe.stories,dataframe.price)

# %%
plt.bar(dataframe.mainroad,dataframe.price)
# Out:
# <BarContainer object of 545 artists>
